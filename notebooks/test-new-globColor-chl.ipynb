# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
data_dir = '/Users/gloege/Documents/Projects/SOCAT-neural-network/data/data_driver/'
fl = data_dir + 'L3m_GLOB_CHL1_199801-201712.nc'
ds = xr.open_dataset(fl)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (lat: 180, lon: 360, record: 240)
# Coordinates:
#   * lat         (lat) float32 89.5 88.5 87.5 86.5 85.5 84.5 83.5 82.5 81.5 ...
#   * lon         (lon) float32 -179.5 -178.5 -177.5 -176.5 -175.5 -174.5 ...
# Dimensions without coordinates: record
# Data variables:
#     CHL1_mean   (record, lat, lon) float32 ...
#     CHL1_flags  (record, lat, lon) float32 ...
# Attributes:
#     Conventions:                CF-1.4
#     title:                      GlobColour monthly SeaWiFS product
#     product_name:               L3m_19980101-19980131__GLOB_100_AV-SWF_CHL1_M...
#     product_type:               month
#     product_version:            2016.1
#     product_level:              3
#     parameter_code:             CHL1
#     parameter:                  Chlorophyll concentration
#     parameter_algo_list:
#     publication:                O'Reilly, J.E., and 24 Coauthors, 2000: SeaWi...
#     site_name:                  GLOB
# ...

# %%
lon = ds['lon']
lat = ds['lat']
chl = ds['CHL1_mean']

# %%
chl.shape
# Out:
# (240, 180, 360)

# %%
plt.pcolor(lon,lat,np.squeeze(chl[-1,:,:]),vmin=0,vmax=1)
plt.colorbar()
plt.show()
